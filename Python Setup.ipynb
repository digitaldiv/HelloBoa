# %% [markdown]
# <a href="https://colab.research.google.com/github/digitaldiv/HelloBoa/blob/main/Python%20Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Setup and configuration : Python
# 1. Setup Python on your computer:
# [Python.org](https://Python.org)
#
#
# 🤔 During the installation do not forget to select the option to "add python into system path".
#
#
#
# 2. Setup VS Code  as Editor on your computer:
# Download Visual Studio Code - Mac, Linux, WindowsLinks to an external site.
#
#
#
# 3. Test Python:
#
# open terminal or command line tool. (term on linux or mac, CMD or Command on Windows)
#
# type "python --version"
#
# If you get a python version info, you are good!!
#
#
#
# 4. Test VS Code:
#
# open terminal or command line tool. (term on linux or mac, CMD or Command on Windows)
#
# type "code ."
#
# if VS Code opens, you are good!!
